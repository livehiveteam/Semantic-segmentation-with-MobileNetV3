# %%
import numpy as np
import os
import cv2
from os.path import join
import tensorflow as tf

from modules.datasets import ImageTargetDataset, RandomConcatDataset

import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
image = image = cv2.imread('data/supervisely/images/woman-portrait-blond-hair.jpg')
target = cv2.imread('data/supervisely/targets/woman-portrait-blond-hair.png')

# %%
type(image)
# Out:
# NoneType

# %%
imgplot = plt.imshow(image)
# Out:
# -----------------------------------------------
# TypeError     Traceback (most recent call last)
# <ipython-input-18-64789df44e04> in <module>
# ----> 1 imgplot = plt.imshow(image)
#
# ~/opt/anaconda3/envs/tfgraph2/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2682         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2683         resample=resample, url=url, **({"data": data} if data is not
# -> 2684         None else {}), **kwargs)
#    2685     sci(__ret)
#    2686     return __ret
#
# ~/opt/anaconda3/envs/tfgraph2/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
# ...

# %%
imgplot = plt.imshow(target*255)
# Out:
# -----------------------------------------------
# TypeError     Traceback (most recent call last)
# <ipython-input-19-1e46e0ffe3ca> in <module>
# ----> 1 imgplot = plt.imshow(target*255)
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %%
imgs = np.load('data/datasets/indian_bro/img_uint8.npy')

# %%
imgs.shape
# Out:
# (18698, 128, 128, 3)

# %%
plt.imshow(imgs[1202])
